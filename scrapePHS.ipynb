# %% [markdown]
# This script updates the csv file containing the Intermediate zone data. It requires manual
# updating of what the newest date data is available from the PHS website.

# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import urllib
import pandas as pd
import datetime as dt

from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry


def updateWeeklyCaseCsv(oldFile, newFile):
    cases = pd.read_csv(newFile, thousands=',')

    casesOlder = pd.read_csv(oldFile, thousands=',')

    izNames = pd.read_csv('scotland-iz.csv')

    cases['dateEnd'] = pd.to_datetime(cases['dateEnd'])
    casesOlder['dateEnd'] = pd.to_datetime(casesOlder['dateEnd'])
    casesOlder = casesOlder.loc[casesOlder['dateEnd'] < min(cases['dateEnd'])]
    cases = cases.append(casesOlder)
    cases = pd.merge(left=cases, right=izNames[['IntZone', 'IntZoneName', 'CAName']], left_on=['council', 'IZ'],
                     right_on=['CAName', 'IntZoneName'])
    cases['IZCode'] = cases['IntZone']
    cases['dateEnd'] = cases['dateEnd'].dt.strftime('%d %B %Y')
    cases = cases[['IZCode', 'council', 'IZ', 'dateStart', 'dateEnd', 'cases', 'pop']]
    cases.drop_duplicates(inplace=True)
    cases.to_csv(oldFile)

# %% [markdown]
# Change the dates below to the select the dates to scrape from the PHS tableau.   Choose the most current date available for the end_date and 4 days before the previous data grab.  Data comes in slowly so most recent data can be revised in new days.

# %%
retry_strategy = Retry(
    total=3,
    status_forcelist=[429, 500, 502, 503, 504],
    method_whitelist=["HEAD", "GET", "OPTIONS","POST"]
)
adapter = HTTPAdapter(max_retries=retry_strategy)

# Definitions
outputFile = 'scotland_weekly_cases_iz.csv'
currentData = pd.read_csv(outputFile, thousands=',')
max(currentData['dateEnd'])

#default to recollect previous 4 days.
start_date =pd.to_datetime(max(currentData['dateEnd']))-dt.timedelta(3)
start_date = start_date.date()

#Alternatively manually set date to start from
#start_date = dt.date(2020, 11, 8)

end_date = dt.date(2020, 11, 8)
end_date_fix = end_date
df = pd.DataFrame(columns=["council", "IZ", "dateStart", "dateEnd", "cases", "pop"])
#List of councils to skip
councilsFinished = []
#councilsFinished = [ "Aberdeen City", "Aberdeenshire"]

# %% [markdown]
# The next section  does the scraping proper.  Can take a while.   It will display what it is getting.  At the end it will update the file.

# %%
errorCount = 0
finished = False

while not finished:
    print("Opening connection to: https://public.tableau.com/views/COVID-19DailyDashboard_15960160643010/Overview")
    try:
        s = requests.Session()
        s.mount("https://", adapter)
        s.mount("http://", adapter)

        data_host = "https://public.tableau.com"

        r = requests.get('https://public.tableau.com/views/COVID-19DailyDashboard_15960160643010/Overview',
            params = {
            ":embed": "y",
            ":showVizHome": "no",
            ":display_count":"y",
            ":display_static_image": "y",
            ":bootstrapWhenNotified": "true",
            ":language": "en-GB",
            "embed":"y",
            ":showVizHome":"n",
            ":apiID":"host0",
        })

        soup = BeautifulSoup(r.text, "html.parser")

        tableauData = json.loads(soup.find("textarea",{"id": "tsConfigContainer"}).text)

        # paramTags = dict([
        #     (t["name"], t["value"])
        #     for t in soup.find("div", {"class":"tableauPlaceholder"}).findAll("param")
        # ])
        #'COVID-19DailyDashboard_15960160643010/Casesbyneighbourhood'



        #https://public.tableau.com/vizql/w/COVID-19DailyDashboard_15960160643010/v/Overview/sessions/2313F4AE03384491BF9A801771048688-0:0/commands/tabsrv/ensure-layout-for-sheet



        #https://public.tableau.com/vizql/w/COVID-19DailyDashboard_15960160643010/v/Overview/sessions/9F3BA709B4024279A38576A3EB91602C-0:0/commands/tabdoc/set-parameter-value

        dataUrl = f'https://public.tableau.com{tableauData["vizql_root"]}/bootstrapSession/sessions/{tableauData["sessionid"]}'
        r2 = requests.post(dataUrl, data= {
        "sheet_id": "Overview",
        "stickySessionKey": urllib.parse.quote_plus(tableauData["stickySessionKey"]),
        # "worksheetPortSize": "%7B%22w%22%3A1050%2C%22h%22%3A1900%7D",
        #    "vizRegionRect": json.dumps({"r": "viz", "x": 496, "y": 148, "w": 0, "h": 0, "fieldVector": None}),
        # "dashboardPortSize":" %7B%22w%22%3A1050%2C%22h%22%3A1900%7D",
        # "clientDimension": "%7B%22w%22%3A516%2C%22h%22%3A727%7D",
        # "renderMapsClientSide": "true",
        # "isBrowserRendering": "true",
        # "browserRenderingThreshold": "100",
        # "formatDataValueLocally": "false",
        # "clientNum":"",
        # "navType": "Reload",
        # "navSrc": "Parse",
        # "devicePixelRatio": "2",
        # "clientRenderPixelLimit": "25000000",
        # "allowAutogenWorksheetPhoneLayouts": "false",
        # "showParams": "%7B%22checkpoint%22%3Afalse%2C%22refresh%22%3Afalse%2C%22refreshUnmodified%22%3Afalse%7D",
        # #"stickySessionKey": "{\"dataserverPermissions\":\"44136fa355b3678a1146ad16f7e8649e94fb4fc21fe77e8310c060f61caaff8a\",\"featureFlags\":\"{\\\"MetricsAuthoringBeta\\\":false}\",\"isAuthoring\":false,\"isOfflineMode\":false,\"lastUpdatedAt\":1603285164529,\"workbookId\":"+f'{tableauData["current_workbook_id"]}'+"}",
        # "filterTileSize": "200",
        # "locale": "en_GB",
        # "language": "en_GB",
        # "verboseMode": "false",
        # ":session_feature_flags": "%7B%7D",
        # "keychain_version": "1",
        })


        dataUrl = f'https://public.tableau.com{tableauData["vizql_root"]}/sessions/{tableauData["sessionid"]}/commands/tabsrv/ensure-layout-for-sheet'
        r3 = requests.post(dataUrl, data= {
            "targetSheet": "Cases by neighbourhood"
        })

        iz = pd.read_csv('scotland-iz.csv')
        councilList = iz.groupby("CAName").size().reset_index(name='count')



        for index, row in councilList.iterrows():


            thisCouncil = row["CAName"]
            numIZ = row["count"]
            if (thisCouncil in councilsFinished):
                continue

            dataUrl = f'https://public.tableau.com{tableauData["vizql_root"]}/sessions/{tableauData["sessionid"]}/commands/tabdoc/set-parameter-value'
            r4 = requests.post(dataUrl, data= {
#                "valueString": urllib.parse.quote_plus(thisCouncil),
                "valueString": thisCouncil,
                "globalFieldName": "[Parameters].[Parameter 1 1]",
                "useUsLocale": "false"
            })

            dataUrl = f'https://public.tableau.com{tableauData["vizql_root"]}/sessions/{tableauData["sessionid"]}/commands/tabsrv/pane-anchor-zoom-server'
            r5 = requests.post(dataUrl, data= {
            "vizRegionRect": json.dumps({"r":"viz","x":537,"y":440}),
            "zoomAnchorPoint": json.dumps({"x":537,"y":440}),
            "zoomFactor": "1.1810923195715735",
            "visualIdPresModel": json.dumps({"worksheet":"IZ_map","dashboard":"Cases by neighbourhood"})
            })

            allTips = []

            numdays = (end_date - start_date).days +1
            date_list = [end_date - dt.timedelta(days=x) for x in range(numdays)]

            for thisDate in range(0,len(date_list),1):

                end_date = date_list[thisDate]
                print(f'Processing: {date_list[thisDate].strftime("%-d %B %Y")}')
                dataUrl = f'https://public.tableau.com{tableauData["vizql_root"]}/sessions/{tableauData["sessionid"]}/commands/tabdoc/categorical-filter'
                rChangeTime = requests.post(dataUrl, data= {
                "visualIdPresModel": json.dumps({"worksheet":"LA_map","dashboard":"Cases by neighbourhood"}),
                "membershipTarget": "filter",
                "globalFieldName": "[federated.09570nd02ojji51547xls1hzn4bs].[md:Date:ok]",
                "filterValues": f'[\"{date_list[thisDate].strftime("%-d %B %Y")}\"]',
                "filterUpdateType": "filter-replace",
                "heuristicCommandReinterpretation": "do-not-reinterpret-command",
                })
                rSave = rChangeTime
                # rChangeTime.json()["vqlCmdResponse"]["layoutStatus"]["applicationPresModel"]["dataDictionary"]["dataSegments"]["1"][
                #     "dataColumns"][0]["dataValues"][3]
                #Data supressed when region has less than 4 cases.
               # if ("Disclosure control applied" in rChangeTime.text) or ("dataDictionary" not in rChangeTime.json()["vqlCmdResponse"]["layoutStatus"]["applicationPresModel"]):
            #    if ("Disclosure control applied" in rChangeTime.text):
                #    print(f'Disclosure control applied for date {date_list[thisDate].strftime("%-d %B %Y")}')
                    #dataUrl = f'https://public.tableau.com{tableauData["vizql_root"]}/sessions/{tableauData["sessionid"]}/commands/tabdoc/categorical-filter'
                   # rReset= requests.post(dataUrl, data={
                    #     "visualIdPresModel": json.dumps({"worksheet": "LA_map", "dashboard": "Cases by neighbourhood"}),
                    #     "membershipTarget": "filter",
                    #     "globalFieldName": "[federated.09570nd02ojji51547xls1hzn4bs].[md:Date:ok]",
                    #     "filterValues": "[\"11 October 2020\"]",
                    #     "filterUpdateType": "filter-replace",
                    #     "heuristicCommandReinterpretation": "do-not-reinterpret-command",
                    # })
                    #
                    # r7July= requests.post(dataUrl, data={
                    #     "visualIdPresModel": json.dumps({"worksheet": "LA_map", "dashboard": "Cases by neighbourhood"}),
                    #     "membershipTarget": "filter",
                    #     "globalFieldName": "[federated.09570nd02ojji51547xls1hzn4bs].[md:Date:ok]",
                    #     "filterValues": "[\"7 July 2020\"]",
                    #     "filterUpdateType": "filter-replace",
                    #     "heuristicCommandReinterpretation": "do-not-reinterpret-command",
                    # })
                    #rSave = rChangeTime
                    #continue

                for i in range(1,numIZ+10):

                    print(f'Requesting zone: {i}')
                    dataUrl = f'https://public.tableau.com{tableauData["vizql_root"]}/sessions/{tableauData["sessionid"]}/commands/tabsrv/render-tooltip-server'
                    r6 = requests.post(dataUrl, data= {
                    "worksheet": "IZ_map",
                    "dashboard": "Cases by neighbourhood",
                    "tupleIds": f'[{i}]',
                    "vizRegionRect": json.dumps({"r":"viz","x":277,"y":332,"w":0,"h":0}),
                    "allowHoverActions": "false",
                    "allowPromptText": "true",
                    "allowWork": "false",
                    "useInlineImages": "true",
                    })
                    tooltipText=r6.json()["vqlCmdResponse"]["cmdResultList"][0]["commandReturn"]["tooltipText"]
                    if not tooltipText:
                        print('No tooltiptext')
                        break
                    tmp=json.loads(tooltipText)
                    if "htmlTooltip" not in tmp:
                        print('no htmlTooltip')
                        break
                    tooltip = tmp["htmlTooltip"]
                    soup = BeautifulSoup(tooltip, "html.parser")

                    allTips.append(soup.text)

                    thisIzTip = soup.find_all('a')

                    df = df.append({
                        "council": thisIzTip[0].get_text(),
                        "IZ": thisIzTip[1].get_text(),
                        "dateStart": thisIzTip[2].get_text(),
                        "dateEnd": thisIzTip[3].get_text(),
                        "cases": thisIzTip[4].get_text(),
                        "pop": soup.find_all('span')[20].get_text()}, ignore_index=True)

                    print(f'Read: {thisIzTip[0].get_text()} {thisIzTip[3].get_text()} {thisIzTip[1].get_text()} {thisIzTip[4].get_text()}' )
                df.to_csv('tmp.csv')
            end_date = end_date_fix #reset end date.
            councilsFinished.append(thisCouncil)
        print('Finished Scraping')

        finished=True
    except KeyboardInterrupt:
        print("Caught Keyboard Interrupt")
        break
    except:
        errorCount = errorCount +1
        print(f'{errorCount} errors happened. Re-establishing connection')
        continue

print('Updating File: ' + outputFile)
updateWeeklyCaseCsv(outputFile, 'tmp.csv')
# Out:
# Top of while loop
# Processing: 7 November 2020
# Requesting zone: 1
# Read: Aberdeen City 07 November 2020 Cummings Park 1-4
# Requesting zone: 2
# Read: Aberdeen City 07 November 2020 West End North 5
# Requesting zone: 3
# Read: Aberdeen City 07 November 2020 Culter 6
# Requesting zone: 4
# Read: Aberdeen City 07 November 2020 Oldmachar West 1-4
# Requesting zone: 5
# Read: Aberdeen City 07 November 2020 Danestone 1-4
# Requesting zone: 6
# Read: Aberdeen City 07 November 2020 Bucksburn South 1-4
# Requesting zone: 7
# Read: Aberdeen City 07 November 2020 Mastrick 1-4
# Requesting zone: 8
# Read: Aberdeen City 07 November 2020 Hilton 6
# Requesting zone: 9
# Read: Aberdeen City 07 November 2020 Ferryhill North 1-4
# Requesting zone: 10
# Read: Aberdeen City 07 November 2020 Braeside, Mannofield, Broomhill and Seafield North 1-4
# Requesting zone: 11
# Read: Aberdeen City 07 November 2020 Northfield 1-4
# Requesting zone: 12
# Read: Aberdeen City 07 November 2020 Seaton 1-4
# Requesting zone: 13
# Read: Aberdeen City 07 November 2020 Froghall, Powis and Sunnybank 1-4
# Requesting zone: 14
# Read: Aberdeen City 07 November 2020 City Centre West 1-4
# Requesting zone: 15
# Read: Aberdeen City 07 November 2020 Balgownie and Donmouth East 1-4
# Requesting zone: 16
# Read: Aberdeen City 07 November 2020 Bucksburn North 1-4
# Requesting zone: 17
# Read: Aberdeen City 07 November 2020 Stockethill 1-4
# Requesting zone: 18
# Read: Aberdeen City 07 November 2020 Hanover North 1-4
# Requesting zone: 19
# Read: Aberdeen City 07 November 2020 Hanover South 1-4
# Requesting zone: 20
# Read: Aberdeen City 07 November 2020 West End South 1-4
# Requesting zone: 21
# Read: Aberdeen City 07 November 2020 Rosemount 1-4
# Requesting zone: 22
# Read: Aberdeen City 07 November 2020 Braeside, Mannofield, Broomhill and Seafield East 1-4
# Requesting zone: 23
# Read: Aberdeen City 07 November 2020 Cults, Bieldside and Milltimber East 1-4
# Requesting zone: 24
# Read: Aberdeen City 07 November 2020 Denmore 1-4
# Requesting zone: 25
# Read: Aberdeen City 07 November 2020 Kingswells 1-4
# Requesting zone: 26
# Read: Aberdeen City 07 November 2020 Sheddocksley 1-4
# Requesting zone: 27
# Read: Aberdeen City 07 November 2020 Woodside 1-4
# Requesting zone: 28
# Read: Aberdeen City 07 November 2020 Kincorth, Leggart and Nigg North 1-4
# Requesting zone: 29
# Read: Aberdeen City 07 November 2020 Ferryhill South 1-4
# Requesting zone: 30
# Read: Aberdeen City 07 November 2020 Midstocket 1-4
# Requesting zone: 31
# Read: Aberdeen City 07 November 2020 Braeside, Mannofield, Broomhill and Seafield South 1-4
# Requesting zone: 32
# Read: Aberdeen City 07 November 2020 Balgownie and Donmouth West 0
# Requesting zone: 33
# Read: Aberdeen City 07 November 2020 Oldmachar East 0
# Requesting zone: 34
# Read: Aberdeen City 07 November 2020 Dyce 0
# Requesting zone: 35
# Read: Aberdeen City 07 November 2020 Heathryfold and Middlefield 0
# Requesting zone: 36
# Read: Aberdeen City 07 November 2020 Tillydrone 0
# Requesting zone: 37
# Read: Aberdeen City 07 November 2020 Old Aberdeen 0
# Requesting zone: 38
# Read: Aberdeen City 07 November 2020 Ashgrove 0
# Requesting zone: 39
# Read: Aberdeen City 07 November 2020 George Street 1-4
# Requesting zone: 40
# Read: Aberdeen City 07 November 2020 Torry East 0
# Requesting zone: 41
# Read: Aberdeen City 07 November 2020 Torry West 0
# Requesting zone: 42
# Read: Aberdeen City 07 November 2020 Cove North 0
# Requesting zone: 43
# Read: Aberdeen City 07 November 2020 Cove South 0
# Requesting zone: 44
# Read: Aberdeen City 07 November 2020 Kincorth, Leggart and Nigg South 0
# Requesting zone: 45
# Read: Aberdeen City 07 November 2020 City Centre East 0
# Requesting zone: 46
# Read: Aberdeen City 07 November 2020 Summerhill 0
# Requesting zone: 47
# Read: Aberdeen City 07 November 2020 Hazlehead 0
# Requesting zone: 48
# Read: Aberdeen City 07 November 2020 Garthdee 0
# Requesting zone: 49
# Read: Aberdeen City 07 November 2020 Cults, Bieldside and Milltimber West 0
# Requesting zone: 50
# no htmlTooltip
# Processing: 7 November 2020
# Requesting zone: 1
# Read: Aberdeenshire 07 November 2020 Fraserburgh Central-Academy 1-4
# Requesting zone: 2
# Read: Aberdeenshire 07 November 2020 Rosehearty and Strathbeg 9
# Requesting zone: 3
# Read: Aberdeenshire 07 November 2020 Peterhead Bay 1-4
# Requesting zone: 4
# Read: Aberdeenshire 07 November 2020 Auchnagatt 1-4
# Requesting zone: 5
# Read: Aberdeenshire 07 November 2020 Longside and Rattray 6
# Requesting zone: 6
# Read: Aberdeenshire 07 November 2020 Mintlaw 1-4
# Requesting zone: 7
# Read: Aberdeenshire 07 November 2020 Inverurie South 5
# Requesting zone: 8
# Read: Aberdeenshire 07 November 2020 Aboyne and South Deeside 1-4
# Requesting zone: 9
# Read: Aberdeenshire 07 November 2020 East Cairngorms 1-4
# Requesting zone: 10
# Read: Aberdeenshire 07 November 2020 Peterhead Harbour 1-4
# Requesting zone: 11
# Read: Aberdeenshire 07 November 2020 Peterhead Links 1-4
# Requesting zone: 12
# Read: Aberdeenshire 07 November 2020 Auchterless and Monquhitter 1-4
# Requesting zone: 13
# Read: Aberdeenshire 07 November 2020 Insch, Oyne and Ythanwells 1-4
# Requesting zone: 14
# Read: Aberdeenshire 07 November 2020 Fyvie-Rothie 1-4
# Requesting zone: 15
# Read: Aberdeenshire 07 November 2020 Banchory West 1-4
# Requesting zone: 16
# Read: Aberdeenshire 07 November 2020 Portlethen 1-4
# Requesting zone: 17
# Read: Aberdeenshire 07 November 2020 Peterhead Ugieside 1-4
# Requesting zone: 18
# Read: Aberdeenshire 07 November 2020 Deer and Mormond 1-4
# Requesting zone: 19
# Read: Aberdeenshire 07 November 2020 Barrahill 1-4
# Requesting zone: 20
# Read: Aberdeenshire 07 November 2020 Inverurie North 1-4
# Requesting zone: 21
# Read: Aberdeenshire 07 November 2020 Banchory-Devenick and Findon 1-4
# Requesting zone: 22
# Read: Aberdeenshire 07 November 2020 Newtonhill 1-4
# Requesting zone: 23
# Read: Aberdeenshire 07 November 2020 Fraserburgh Smiddyhill 1-4
# Requesting zone: 24
# Read: Aberdeenshire 07 November 2020 Clashindarroch 1-4
# Requesting zone: 25
# Read: Aberdeenshire 07 November 2020 Ythsie 1-4
# Requesting zone: 26
# Read: Aberdeenshire 07 November 2020 Ythanside 1-4
# Requesting zone: 27
# Read: Aberdeenshire 07 November 2020 Ellon West 1-4
# Requesting zone: 28
# Read: Aberdeenshire 07 November 2020 Balmedie and Potterton 1-4
# Requesting zone: 29
# Read: Aberdeenshire 07 November 2020 Newmachar and Fintray 1-4
# Requesting zone: 30
# Read: Aberdeenshire 07 November 2020 Garlogie and Elrick 1-4
# Requesting zone: 31
# Read: Aberdeenshire 07 November 2020 Blackburn 1-4
# Requesting zone: 32
# Read: Aberdeenshire 07 November 2020 Howe of Alford 1-4
# Requesting zone: 33
# Read: Aberdeenshire 07 November 2020 Crathes and Torphins 1-4
# Requesting zone: 34
# Read: Aberdeenshire 07 November 2020 Mearns North and Inverbervie 1-4
# Requesting zone: 35
# Read: Aberdeenshire 07 November 2020 Fraserburgh Harbour and Broadsea 0
# Requesting zone: 36
# Read: Aberdeenshire 07 November 2020 Fraserburgh Lochpots 0
# Requesting zone: 37
# Read: Aberdeenshire 07 November 2020 Cruden 0
# Requesting zone: 38
# Read: Aberdeenshire 07 November 2020 New Pitsligo 0
# Requesting zone: 39
# Read: Aberdeenshire 07 November 2020 Gardenstown and King Edward 0
# Requesting zone: 40
# Read: Aberdeenshire 07 November 2020 Macduff 0
# Requesting zone: 41
# Read: Aberdeenshire 07 November 2020 Banff 0
# Requesting zone: 42
# Read: Aberdeenshire 07 November 2020 Aberchirder and Whitehills 0
# Requesting zone: 43
# Read: Aberdeenshire 07 November 2020 Portsoy, Fordyce and Cornhill 0
# Requesting zone: 44
# Read: Aberdeenshire 07 November 2020 Turriff 0
# Requesting zone: 45
# Read: Aberdeenshire 07 November 2020 Huntly 0
# Requesting zone: 46
# Read: Aberdeenshire 07 November 2020 Ellon East 0
# Requesting zone: 47
# Read: Aberdeenshire 07 November 2020 Westhill Central 0
# Requesting zone: 48
# Read: Aberdeenshire 07 November 2020 Westhill North and South 0
# Requesting zone: 49
# Read: Aberdeenshire 07 November 2020 Kintore 0
# Requesting zone: 50
# Read: Aberdeenshire 07 November 2020 Durno-Chapel of Garioch 0
# Requesting zone: 51
# Read: Aberdeenshire 07 November 2020 Kemnay 0
# Requesting zone: 52
# Read: Aberdeenshire 07 November 2020 Cromar and Kildrummy 0
# Requesting zone: 53
# Read: Aberdeenshire 07 November 2020 Banchory East 0
# Requesting zone: 54
# Read: Aberdeenshire 07 November 2020 Dunecht, Durris and Drumoak 0
# Requesting zone: 55
# Read: Aberdeenshire 07 November 2020 Stonehaven North 0
# Requesting zone: 56
# Read: Aberdeenshire 07 November 2020 Stonehaven South 0
# Requesting zone: 57
# Read: Aberdeenshire 07 November 2020 Fetteresso, Netherley and Catter 0
# Requesting zone: 58
# Read: Aberdeenshire 07 November 2020 Mearns South and Benholm 0
# Requesting zone: 59
# Read: Aberdeenshire 07 November 2020 Mearns and Laurencekirk 0
# Requesting zone: 60
# no htmlTooltip
# Processing: 7 November 2020
# Requesting zone: 1
# Read: Angus 07 November 2020 Angus Glens 5
# Requesting zone: 2
# Read: Angus 07 November 2020 Kirriemuir Landward 5
# Requesting zone: 3
# Read: Angus 07 November 2020 Forfar East 6
# Requesting zone: 4
# Read: Angus 07 November 2020 Arbroath Cliffburn 6
# Requesting zone: 5
# Read: Angus 07 November 2020 Arbroath Harbour 6
# Requesting zone: 6
# Read: Angus 07 November 2020 Arbroath Keptie 1-4
# Requesting zone: 7
# Read: Angus 07 November 2020 Arbroath Landward 6
# Requesting zone: 8
# Read: Angus 07 November 2020 Carnoustie West 8
# Requesting zone: 9
# Read: Angus 07 November 2020 Monifieth East 6
# Requesting zone: 10
# Read: Angus 07 November 2020 Monifieth West 9
# Requesting zone: 11
# Read: Angus 07 November 2020 Monikie 9
# Requesting zone: 12
# Read: Angus 07 November 2020 Arbroath Kirkton 5
# Requesting zone: 13
# Read: Angus 07 November 2020 Friockheim 1-4
# Requesting zone: 14
# Read: Angus 07 November 2020 Hillside 1-4
# Requesting zone: 15
# Read: Angus 07 November 2020 Arbroath Warddykes 1-4
# Requesting zone: 16
# Read: Angus 07 November 2020 Carnoustie East 1-4
# Requesting zone: 17
# Read: Angus 07 November 2020 South Angus 1-4
# Requesting zone: 18
# Read: Angus 07 November 2020 Kirriemuir 1-4
# Requesting zone: 19
# Read: Angus 07 November 2020 Forfar West 1-4
# Requesting zone: 20
# Read: Angus 07 November 2020 Letham and Glamis 1-4
# Requesting zone: 21
# Read: Angus 07 November 2020 Lunan 1-4
# Requesting zone: 22
# Read: Angus 07 November 2020 Forfar Central 0
# Requesting zone: 23
# Read: Angus 07 November 2020 Brechin West 0
# Requesting zone: 24
# Read: Angus 07 November 2020 Brechin East 0
# Requesting zone: 25
# Read: Angus 07 November 2020 Montrose North 0
# Requesting zone: 26
# Read: Angus 07 November 2020 Montrose South 0
# Requesting zone: 27
# no htmlTooltip
# Processing: 7 November 2020
# Requesting zone: 1
# Read: Argyll & Bute 07 November 2020 Helensburgh Centre 1-4
# Requesting zone: 2
# Read: Argyll & Bute 07 November 2020 Helensburgh North 8
# Requesting zone: 3
# Read: Argyll & Bute 07 November 2020 Hunter's Quay 6
# Requesting zone: 4
# Read: Argyll & Bute 07 November 2020 Mull, Iona, Coll and Tiree 1-4
# Requesting zone: 5
# Read: Argyll & Bute 07 November 2020 Helensburgh West and Rhu 1-4
# Requesting zone: 6
# Read: Argyll & Bute 07 November 2020 Cowal North 1-4
# Requesting zone: 7
# Read: Argyll & Bute 07 November 2020 Garelochhead 1-4
# Requesting zone: 8
# Read: Argyll & Bute 07 November 2020 Dunoon 1-4
# Requesting zone: 9
# Read: Argyll & Bute 07 November 2020 Kintyre Trail 1-4
# Requesting zone: 10
# Read: Argyll & Bute 07 November 2020 Oban South 1-4
# Requesting zone: 11
# Read: Argyll & Bute 07 November 2020 Lomond Shore 1-4
# Requesting zone: 12
# Read: Argyll & Bute 07 November 2020 Mid Argyll 1-4
# Requesting zone: 13
# Read: Argyll & Bute 07 November 2020 Whisky Isles 1-4
# Requesting zone: 14
# Read: Argyll & Bute 07 November 2020 Greater Lochgilphead 1-4
# Requesting zone: 15
# Read: Argyll & Bute 07 November 2020 Helensburgh East 0
# Requesting zone: 16
# Read: Argyll & Bute 07 November 2020 Cowal South 0
# Requesting zone: 17
# Read: Argyll & Bute 07 November 2020 Rothesay Town 0
# Requesting zone: 18
# Read: Argyll & Bute 07 November 2020 Bute 0
# Requesting zone: 19
# Read: Argyll & Bute 07 November 2020 Campbeltown 0
# Requesting zone: 20
# Read: Argyll & Bute 07 November 2020 Knapdale 0
# Requesting zone: 21
# Read: Argyll & Bute 07 November 2020 Loch Awe 0
# Requesting zone: 22
# Read: Argyll & Bute 07 November 2020 Benderloch Trail 0
# Requesting zone: 23
# Read: Argyll & Bute 07 November 2020 Oban North 0
# Requesting zone: 24
# no htmlTooltip
# Processing: 7 November 2020
# Requesting zone: 1
# Read: City of Edinburgh 07 November 2020 Queensferry West 1-4
# Requesting zone: 2
# Read: City of Edinburgh 07 November 2020 Ratho, Ingliston and Gogar 1-4
# Requesting zone: 3
# Read: City of Edinburgh 07 November 2020 Corstorphine 8
# Requesting zone: 4
# Read: City of Edinburgh 07 November 2020 East Craigs North 5
# Requesting zone: 5
# Read: City of Edinburgh 07 November 2020 Boswall and Pilton 6
# Requesting zone: 6
# Read: City of Edinburgh 07 November 2020 West Pilton 12
# Requesting zone: 7
# Read: City of Edinburgh 07 November 2020 Drylaw 6
# Requesting zone: 8
# Read: City of Edinburgh 07 November 2020 Deans Village 11
# Requesting zone: 9
# Read: City of Edinburgh 07 November 2020 Comely Bank 5
# Requesting zone: 10
# Read: City of Edinburgh 07 November 2020 New Town East and Gayfield 1-4
# Requesting zone: 11
# Read: City of Edinburgh 07 November 2020 Hillside and Calton Hill 7
# Requesting zone: 12
# Read: City of Edinburgh 07 November 2020 Leith (Albert Street) 1-4
# Requesting zone: 13
# Read: City of Edinburgh 07 November 2020 Easter Road and Hawkhill Avenue 1-4
# Requesting zone: 14
# Read: City of Edinburgh 07 November 2020 Craigentinny 1-4
# Requesting zone: 15
# Read: City of Edinburgh 07 November 2020 Mountcastle 1-4
# Requesting zone: 16
# Read: City of Edinburgh 07 November 2020 Niddrie 12
# Requesting zone: 17
# Read: City of Edinburgh 07 November 2020 Craigmillar 7
# Requesting zone: 18
# Read: City of Edinburgh 07 November 2020 Willowbrae and Duddingston Village 7
# Requesting zone: 19
# Read: City of Edinburgh 07 November 2020 Old Town, Princes Street and Leith Street 12
# Requesting zone: 20
# Read: City of Edinburgh 07 November 2020 Dalry and Fountainbridge 12
# Requesting zone: 21
# Read: City of Edinburgh 07 November 2020 Polwarth 6
# Requesting zone: 22
# Read: City of Edinburgh 07 November 2020 Bruntsfield 6
# Requesting zone: 23
# Read: City of Edinburgh 07 November 2020 Merchiston and Greenhill 6
# Requesting zone: 24
# Read: City of Edinburgh 07 November 2020 Marchmont West 7
# Requesting zone: 25
# Read: City of Edinburgh 07 November 2020 Newington and Dalkeith Road 20
# Requesting zone: 26
# Read: City of Edinburgh 07 November 2020 The Inch 7
# Requesting zone: 27
# Read: City of Edinburgh 07 November 2020 Liberton West and Braid Hills 1-4
# Requesting zone: 28
# Read: City of Edinburgh 07 November 2020 Liberton East 9
# Requesting zone: 29
# Read: City of Edinburgh 07 November 2020 Hyvots and Gilmerton 5
# Requesting zone: 30
# Read: City of Edinburgh 07 November 2020 Gilmerton South and the Murrays 6
# Requesting zone: 31
# Read: City of Edinburgh 07 November 2020 Oxgangs 6
# Requesting zone: 32
# Read: City of Edinburgh 07 November 2020 Shandon 6
# Requesting zone: 33
# Read: City of Edinburgh 07 November 2020 Gorgie East 5
# Requesting zone: 34
# Read: City of Edinburgh 07 November 2020 Broomhouse and Bankhead 1-4
# Requesting zone: 35
# Read: City of Edinburgh 07 November 2020 Clovenstone and Wester Hailes 6
# Requesting zone: 36
# Read: City of Edinburgh 07 November 2020 Currie East 1-4
# Requesting zone: 37
# Read: City of Edinburgh 07 November 2020 Currie West 12
# Requesting zone: 38
# Read: City of Edinburgh 07 November 2020 Balerno and Bonnington Village 6
# Requesting zone: 39
# Read: City of Edinburgh 07 November 2020 Corstorphine North 1-4
# Requesting zone: 40
# Read: City of Edinburgh 07 November 2020 East Craigs South 5
# Requesting zone: 41
# Caught Keyboard Interrupt
